# %%
import requests

url = "http://localhost:5678/webhook-test/68247e60-fe0e-47fc-8a9e-0299812a4167"
payload = { "ip": "1.2.3.4", "level": 10, "rule": "5712" }
r = requests.post(url, json=payload)
print(r.status_code)
# Out:
# 200
